# %%
# %load_ext autoreload
# %autoreload 2
from vector_drawing import *

# %% [markdown]
# Exercise 2.29

# %%
from math import sqrt, cos, sin, pi

angle = 37 * pi/180
x = round(15 * cos(angle))
y = round(15 * sin(angle))
print((x, y))
# Out:
# (12, 9)
